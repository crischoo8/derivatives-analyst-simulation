# %% [markdown]
# # Week 1 — Market Orientation
# **Date started:**  6 May 2026\
# **Program:** Derivatives Analyst Simulation
# **Mentor review:** Pending

# %% [markdown]
# ## Objective
# [Leave blank for now — fill this in when Week 1 brief is available]

# %% [markdown]
# ## Deliverable
# [Leave blank for now]

# %% [markdown]
# ## My work

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
print("Environment ready.")
# Out:
# Environment ready.
